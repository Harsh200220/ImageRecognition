# %%
import numpy as np

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
filename = 'DataSet\\bike1.jpeg'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 776ms/step

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03792782', 'mountain_bike', 0.86948115), ('n03208938', 'disk_brake', 0.022633292), ('n04482393', 'tricycle', 0.0150647415), ('n03785016', 'moped', 0.0064041945), ('n02835271', 'bicycle-built-for-two', 0.005613334)]]

# %%
plt.imshow(img)
