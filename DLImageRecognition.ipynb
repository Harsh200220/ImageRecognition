# %%
import numpy as np

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
filename = 'DataSet\bike1.jpeg'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 2
#       1 from tensorflow.keras.preprocessing import image
# ----> 2 img = image.load_img(filename, target_size = (224,224))
#
# File c:\Users\91902\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# OSError: [Errno 22] Invalid argument: 'DataSet\x08ike1.jpeg'

# %%
plt.imshow(img)

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()
# mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# resized_img = image.img_to_array(img)
# final_image = np.expand_dims(resized_img,axis=0)
# final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
from tensorflow.keras.applications import imagenet_utils

# from tensorflow.keras.applications import imagenet_utils

# %%
predictions = mobile.predict(final_image)
# predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 833ms/step

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03673027', 'liner', 0.8887839), ('n02981792', 'catamaran', 0.017070899), ('n04273569', 'speedboat', 0.0069032847), ('n03344393', 'fireboat', 0.0027579544), ('n04347754', 'submarine', 0.0020289156)]]

# %%
plt.imshow(img)
